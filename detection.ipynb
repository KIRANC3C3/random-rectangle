# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\kiran\anaconda3\lib\site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\kiran\anaconda3\lib\site-packages (from opencv-python) (1.21.5)

# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# pdf_input=input()
# convert pdf to png
# image_png=

# %%
image1=cv2.imread('50.png')#image_png
image=cv2.resize(image1,(1500,1500))
gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
plt.imshow(gray,cmap='gray')

# %%
blur=cv2.GaussianBlur(gray,(11,11),0)
plt.imshow(blur,cmap='gray')

# %%
"""thresh = cv2.threshold(src=gray,
                       thresh=60,
                       maxval=1200,
                       type=cv2.THRESH_BINARY_INV)[1]
#thresh = cv2.threshold(blur, 60, 255, cv2.THRESH_BINARY)[1]
plt.imshow(thresh,cmap='gray')"""
# Out:
# "thresh = cv2.threshold(src=gray,\n                       thresh=60,\n                       maxval=1200,\n                       type=cv2.THRESH_BINARY_INV)[1]\n#thresh = cv2.threshold(blur, 60, 255, cv2.THRESH_BINARY)[1]\nplt.imshow(thresh,cmap='gray')"

# %%
canny=cv2.Canny(blur,30,150,3)
plt.imshow(canny,cmap='gray')

# %%
dilated=cv2.dilate(canny,(1,1),iterations=2)
plt.imshow(dilated,cmap='gray')

# %%
(cnt,heirarchy)=cv2.findContours(dilated.copy(),cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_NONE)
rgb=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
cv2.drawContours(rgb,cnt,-1,(0,0,255),5)
plt.imshow(rgb)

# %%
print('rectangle in the image:',len(cnt))
# Out:
# rectangle in the image: 46

# %%
cen=[]
for c in cnt:
        if cv2.contourArea(c) <= 150 :
            continue    
        x,y,w,h = cv2.boundingRect(c)
        cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255,0), 2)
        center = (x,y)
        cen.append(center)
        height_width=(w,h)
        print (center)
        
        print(height_width)
        print('----------------------------------')
# Out:
# (544, 1398)
# (112, 29)
# ----------------------------------
# (856, 1393)
# (30, 34)
# ----------------------------------
# (75, 1367)
# (86, 60)
# ----------------------------------
# (700, 1348)
# (130, 79)
# ----------------------------------
# (1168, 1347)
# (101, 80)
# ----------------------------------
# (387, 1335)
# (98, 92)
# ----------------------------------
# (231, 1333)
# (98, 94)
# ----------------------------------
# (1012, 1313)
# (110, 114)
# ----------------------------------
# (700, 1235)
# (114, 36)
# ----------------------------------
# (1168, 1230)
# (158, 41)
# ----------------------------------
# (856, 1208)
# (134, 63)
# ----------------------------------
# (387, 1171)
# (134, 100)
# ----------------------------------
# (1012, 1132)
# (84, 139)
# ----------------------------------
# (75, 1127)
# (110, 144)
# ----------------------------------
# (544, 1125)
# (110, 146)
# ----------------------------------
# (231, 1125)
# (70, 146)
# ----------------------------------
# (856, 1082)
# (106, 32)
# ----------------------------------
# (700, 1076)
# (118, 38)
# ----------------------------------
# (231, 1076)
# (25, 38)
# ----------------------------------
# (1012, 1035)
# (95, 79)
# ----------------------------------
# (387, 1002)
# (117, 112)
# ----------------------------------
# (544, 996)
# (90, 118)
# ----------------------------------
# (1168, 992)
# (73, 122)
# ----------------------------------
# (75, 986)
# (152, 128)
# ----------------------------------
# (856, 925)
# (125, 33)
# ----------------------------------
# (544, 919)
# (135, 39)
# ----------------------------------
# (1012, 915)
# (145, 43)
# ----------------------------------
# (231, 882)
# (82, 76)
# ----------------------------------
# (1168, 831)
# (152, 127)
# ----------------------------------
# (387, 818)
# (100, 140)
# ----------------------------------
# (75, 818)
# (154, 140)
# ----------------------------------
# (700, 817)
# (99, 141)
# ----------------------------------
# (700, 769)
# (102, 33)
# ----------------------------------
# (856, 746)
# (129, 56)
# ----------------------------------
# (1012, 707)
# (20, 95)
# ----------------------------------
# (75, 677)
# (446, 125)
# ----------------------------------
# (544, 672)
# (97, 130)
# ----------------------------------
# (1168, 670)
# (21, 132)
# ----------------------------------
# (231, 572)
# (134, 74)
# ----------------------------------
# (856, 556)
# (75, 90)
# ----------------------------------
# (544, 545)
# (262, 101)
# ----------------------------------
# (75, 544)
# (54, 102)
# ----------------------------------
# (1168, 522)
# (137, 124)
# ----------------------------------
# (387, 521)
# (126, 125)
# ----------------------------------
# (1012, 509)
# (129, 137)
# ----------------------------------
# (75, 421)
# (179, 68)
# ----------------------------------

# %%
print('total ',len(cen))
# Out:
# total  46
